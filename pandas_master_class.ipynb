# %% [markdown]
# <a href="https://colab.research.google.com/github/GursharanGrewal/panda-basic/blob/main/pandas_master_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Motu")
# Out:
# Hello Motu

# %%
4*5
# Out:
# 20

# %%
import pandas as pd

# %%
# !wget "https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_" -O data.csv
# Out:
# --2023-10-28 12:37:38--  https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# Resolving drive.google.com (drive.google.com)... 142.251.167.113, 142.251.167.102, 142.251.167.100, ...
# Connecting to drive.google.com (drive.google.com)|142.251.167.113|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0s-68-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/32d0ogsoo1165i0636325udnlkj1uv7p/1698496650000/14302370361230157278/*/1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_?e=download&uuid=5f0591a6-68e7-4720-9e28-c318d618bd6a [following]
# ...
# --2023-10-28 12:37:38--  https://doc-0s-68-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/32d0ogsoo1165i0636325udnlkj1uv7p/1698496650000/14302370361230157278/*/1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_?e=download&uuid=5f0591a6-68e7-4720-9e28-c318d618bd6a
# ...

# %%
df = pd.read_csv("data.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]>

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.tail()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   object
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
df.describe()
# Out:
#              year    population     life_exp        gdp_cap
# count  1704.00000  1.704000e+03  1704.000000    1704.000000
# mean   1979.50000  2.960121e+07    59.474439    7215.327081
# std      17.26533  1.061579e+08    12.917107    9857.454543
# min    1952.00000  6.001100e+04    23.599000     241.165876
# 25%    1965.75000  2.793664e+06    48.198000    1202.060309
# 50%    1979.50000  7.023596e+06    60.712500    3531.846988
# 75%    1993.25000  1.958522e+07    70.845500    9325.462346
# max    2007.00000  1.318683e+09    82.603000  113523.132900

# %%
df["life_exp"]
# Out:
# 0       28.801
# 1       30.332
# 2       31.997
# 3       34.020
# 4       36.088
#          ...
# 1699    62.351
# 1700    60.377
# 1701    46.809
# 1702    39.989
# 1703    43.487
# Name: life_exp, Length: 1704, dtype: float64

# %%
df.life_exp
# Out:
# 0       28.801
# 1       30.332
# 2       31.997
# 3       34.020
# 4       36.088
#          ...
# 1699    62.351
# 1700    60.377
# 1701    46.809
# 1702    39.989
# 1703    43.487
# Name: life_exp, Length: 1704, dtype: float64

# %%
min_exp = df["life_exp"].min()
print(min_exp)
# Out:
# 23.599

# %%
df["life_exp"] == min_exp
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703    False
# Name: life_exp, Length: 1704, dtype: bool

# %%
true_false_val = df["life_exp"] == min_exp
df[true_false_val]
# Out:
#      country  year  population continent  life_exp     gdp_cap
# 1292  Rwanda  1992     7290203    Africa    23.599  737.068595

# %%
max_exp = df["life_exp"].max()
true_false_value = df["life_exp"] == max_exp
df[true_false_value]
# Out:
#     country  year  population continent  life_exp      gdp_cap
# 803   Japan  2007   127467972      Asia    82.603  31656.06806

# %%
df['country'] == 'India'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703    False
# Name: country, Length: 1704, dtype: bool

# %%
df_India = df[df['country'] == 'India']
df_India
# Out:
#     country  year  population continent  life_exp      gdp_cap
# 696   India  1952   372000000      Asia    37.373   546.565749
# 697   India  1957   409000000      Asia    40.249   590.061996
# 698   India  1962   454000000      Asia    43.605   658.347151
# 699   India  1967   506000000      Asia    47.193   700.770611
# 700   India  1972   567000000      Asia    50.651   724.032527
# 701   India  1977   634000000      Asia    54.208   813.337323
# 702   India  1982   708000000      Asia    56.596   855.723538
# 703   India  1987   788000000      Asia    58.553   976.512676
# 704   India  1992   872000000      Asia    60.223  1164.406809
# 705   India  1997   959000000      Asia    61.765  1458.817442
# 706   India  2002  1034172547      Asia    62.879  1746.769454
# 707   India  2007  1110396331      Asia    64.698  2452.210407

# %%
df_India.describe()
# Out:
#               year    population   life_exp      gdp_cap
# count    12.000000  1.200000e+01  12.000000    12.000000
# mean   1979.500000  7.011307e+08  53.166083  1057.296307
# std      18.027756  2.517243e+08   9.257068   570.248221
# min    1952.000000  3.720000e+08  37.373000   546.565749
# 25%    1965.750000  4.930000e+08  46.296000   690.164746
# 50%    1979.500000  6.710000e+08  55.402000   834.530430
# 75%    1993.250000  8.937500e+08  60.608500  1238.009467
# max    2007.000000  1.110396e+09  64.698000  2452.210407

# %%
df_India.plot("year","gdp_cap")
# Out:
# <Axes: xlabel='year'>

# %%
df_India.plot("year","life_exp")
# Out:
# <Axes: xlabel='year'>

# %%
df_India.plot("year","population")
# Out:
# <Axes: xlabel='year'>

# %%
df_India.plot("population","gdp_cap")
# Out:
# <Axes: xlabel='population'>
